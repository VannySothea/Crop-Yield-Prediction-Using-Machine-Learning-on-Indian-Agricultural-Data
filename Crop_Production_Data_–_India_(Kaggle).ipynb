# %% [markdown]
# <a href="https://colab.research.google.com/github/VannySothea/Crop-Yield-Prediction-Using-Machine-Learning-on-Indian-Agricultural-Data/blob/main/Crop_Production_Data_%E2%80%93_India_(Kaggle).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/India Agriculture Crop Production.csv')

# %% [markdown]
# About Dataset
# India District-wise agriculture crop area and production statistics 1997-2021
# Latest update 02.2023.
# Next update of dataset is scheduled in Summer 2023.
#
# Data collected from Ministry of Agriculture and Farmers Welfare of India
# Kudos to them!
#
# Due to limitations at source data is only partially available for the most recent years:
#
# 2019-20 season - data available on 33 of 35 states and territories
# 2020-21 season - data available on 1 of 35 states and territories

# %%
df
# Out:
#                              State                  District  \
# 0      Andaman and Nicobar Islands                  NICOBARS
# 1      Andaman and Nicobar Islands                  NICOBARS
# 2      Andaman and Nicobar Islands                  NICOBARS
# 3      Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN
# 4      Andaman and Nicobar Islands            SOUTH ANDAMANS
# ...                            ...                       ...
# 46471                        Assam                 SIVASAGAR
# 46472                        Assam                  SONITPUR
# 46473                        Assam                  SONITPUR
# 46474                        Assam                  SONITPUR
# 46475                        Assam                  TINSUKIA
#
#                         Crop     Year      Season    Area Area Units  \
# 0                   Arecanut  2001-02      Kharif  1254.0    Hectare
# 1                   Arecanut  2002-03  Whole Year  1258.0    Hectare
# ...

# %%
df.columns
# Out:
# Index(['State', 'District', 'Crop', 'Year', 'Season', 'Area', 'Area Units',
#        'Production', 'Production Units', 'Yield'],
#       dtype='object')

# %%
df.shape
# Out:
# (46476, 10)

# %%
df.describe()
# Out:
#                Area    Production         Yield
# count  4.647500e+04  4.610500e+04  46475.000000
# mean   1.134819e+04  8.353499e+05     85.292086
# std    3.709834e+04  1.812560e+07    902.328513
# min    2.000000e-01  0.000000e+00      0.000000
# 25%    9.500000e+01  9.500000e+01      0.481481
# 50%    6.560000e+02  7.170000e+02      0.930303
# 75%    4.538000e+03  6.709000e+03      2.055433
# max    1.020181e+06  8.980000e+08  28334.155972

# %% [markdown]
#  extract the year part from a string and convert it to an integer

# %%
df.head()
# Out:
#                          State                  District      Crop     Year  \
# 0  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2001-02
# 1  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2002-03
# 2  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2003-04
# 3  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut  2001-02
# 4  Andaman and Nicobar Islands            SOUTH ANDAMANS  Arecanut  2002-03
#
#        Season    Area Area Units  Production Production Units     Yield
# 0      Kharif  1254.0    Hectare      2061.0           Tonnes  1.643541
# 1  Whole Year  1258.0    Hectare      2083.0           Tonnes  1.655803
# 2  Whole Year  1261.0    Hectare      1525.0           Tonnes  1.209358
# 3      Kharif  3100.0    Hectare      5239.0           Tonnes  1.690000
# 4  Whole Year  3105.0    Hectare      5267.0           Tonnes  1.696296

# %%
df.tail()
# Out:
#        State   District                   Crop     Year Season    Area  \
# 46471  Assam  SIVASAGAR  Peas & beans (Pulses)  2006-07   Rabi   203.0
# 46472  Assam   SONITPUR  Peas & beans (Pulses)  2004-05   Rabi  2192.0
# 46473  Assam   SONITPUR  Peas & beans (Pulses)  2005-06   Rabi  1866.0
# 46474  Assam   SONITPUR  Peas & beans (Pulses)  2006-07   Rabi  2225.0
# 46475  Assam   TINSUKIA              Peas & be      NaN    NaN     NaN
#
#       Area Units  Production Production Units     Yield
# 46471    Hectare       126.0           Tonnes  0.620690
# 46472    Hectare      1157.0           Tonnes  0.527828
# 46473    Hectare      1022.0           Tonnes  0.547696
# 46474    Hectare      1188.0           Tonnes  0.533933
# 46475        NaN         NaN              NaN       NaN

# %%
df = df.drop(46475)

# %%
df.tail()
# Out:
#        State   District                   Crop     Year Season    Area  \
# 46470  Assam  SIVASAGAR  Peas & beans (Pulses)  2005-06   Rabi   225.0
# 46471  Assam  SIVASAGAR  Peas & beans (Pulses)  2006-07   Rabi   203.0
# 46472  Assam   SONITPUR  Peas & beans (Pulses)  2004-05   Rabi  2192.0
# 46473  Assam   SONITPUR  Peas & beans (Pulses)  2005-06   Rabi  1866.0
# 46474  Assam   SONITPUR  Peas & beans (Pulses)  2006-07   Rabi  2225.0
#
#       Area Units  Production Production Units     Yield
# 46470    Hectare       129.0           Tonnes  0.573333
# 46471    Hectare       126.0           Tonnes  0.620690
# 46472    Hectare      1157.0           Tonnes  0.527828
# 46473    Hectare      1022.0           Tonnes  0.547696
# 46474    Hectare      1188.0           Tonnes  0.533933

# %%
df['Year'] = df['Year'].str[:4].astype(int)

# %%
df
# Out:
#                              State                  District  \
# 0      Andaman and Nicobar Islands                  NICOBARS
# 1      Andaman and Nicobar Islands                  NICOBARS
# 2      Andaman and Nicobar Islands                  NICOBARS
# 3      Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN
# 4      Andaman and Nicobar Islands            SOUTH ANDAMANS
# ...                            ...                       ...
# 46470                        Assam                 SIVASAGAR
# 46471                        Assam                 SIVASAGAR
# 46472                        Assam                  SONITPUR
# 46473                        Assam                  SONITPUR
# 46474                        Assam                  SONITPUR
#
#                         Crop  Year      Season    Area Area Units  Production  \
# 0                   Arecanut  2001      Kharif  1254.0    Hectare      2061.0
# ...

# %%
df = df.dropna()
df = df.drop('Area Units',axis = 1)

# %%
df["Production Units"].unique()
# Out:
# array(['Tonnes', 'Nuts', 'Bales'], dtype=object)

# %%
df["Crop"].unique()
# Out:
# array(['Arecanut', 'Banana', 'Black pepper', 'Cashewnut', 'Coconut',
#        'Dry chillies', 'Ginger', 'Other Kharif pulses', 'other oilseeds',
#        'Rice', 'Sugarcane', 'Sweet potato', 'Arhar/Tur', 'Bajra',
#        'Castor seed', 'Coriander', 'Cotton(lint)', 'Gram', 'Groundnut',
#        'Horse-gram', 'Jowar', 'Linseed', 'Maize', 'Mesta',
#        'Moong(Green Gram)', 'Niger seed', 'Onion', 'Other Rabi pulses',
#        'Potato', 'Ragi', 'Rapeseed &Mustard', 'Safflower', 'Sesamum',
#        'Small millets', 'Soyabean', 'Sunflower', 'Tapioca', 'Tobacco',
#        'Turmeric', 'Urad', 'Wheat', 'Oilseeds total', 'Jute', 'Masoor',
#        'Peas & beans (Pulses)', 'Barley', 'Garlic', 'Khesari', 'Sannhamp',
#        'Guar seed', 'Moth', 'Cardamom', 'Other Cereals'], dtype=object)

# %%
df.loc[df['Crop'] == 'Cotton(lint)','Production'] = (df.loc[df['Crop'] == 'Cotton(lint)','Production']*170)/1000
df.loc[df['Crop'] == 'Jute','Production'] = (df.loc[df['Crop'] == 'Jute','Production']*180)/1000
df.loc[df['Crop'] == 'Mesta','Production'] = (df.loc[df['Crop'] == 'Mesta','Production']*180)/1000
df.loc[df['Crop'] == 'Coconut','Production'] = (df.loc[df['Crop'] == 'Coconut','Production']*1.5)/1000
df = df.drop('Production Units',axis = 1)

# %%
df = df.drop('Yield',axis = 1)
df['Yield'] = df['Production'] / df['Area']

# %%
df
# Out:
#                              State                  District  \
# 0      Andaman and Nicobar Islands                  NICOBARS
# 1      Andaman and Nicobar Islands                  NICOBARS
# 2      Andaman and Nicobar Islands                  NICOBARS
# 3      Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN
# 4      Andaman and Nicobar Islands            SOUTH ANDAMANS
# ...                            ...                       ...
# 46470                        Assam                 SIVASAGAR
# 46471                        Assam                 SIVASAGAR
# 46472                        Assam                  SONITPUR
# 46473                        Assam                  SONITPUR
# 46474                        Assam                  SONITPUR
#
#                         Crop  Year      Season    Area  Production     Yield
# 0                   Arecanut  2001      Kharif  1254.0      2061.0  1.643541
# 1                   Arecanut  2002  Whole Year  1258.0      2083.0  1.655803
# ...

# %%
df['Area'] = np.log1p(df['Area'])
df['Production'] = np.log1p(df['Production'])

# %%
df
# Out:
#                              State                  District  \
# 0      Andaman and Nicobar Islands                  NICOBARS
# 1      Andaman and Nicobar Islands                  NICOBARS
# 2      Andaman and Nicobar Islands                  NICOBARS
# 3      Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN
# 4      Andaman and Nicobar Islands            SOUTH ANDAMANS
# ...                            ...                       ...
# 46470                        Assam                 SIVASAGAR
# 46471                        Assam                 SIVASAGAR
# 46472                        Assam                  SONITPUR
# 46473                        Assam                  SONITPUR
# 46474                        Assam                  SONITPUR
#
#                         Crop  Year      Season      Area  Production     Yield
# 0                   Arecanut  2001      Kharif  7.134891    7.631432  1.643541
# ...
